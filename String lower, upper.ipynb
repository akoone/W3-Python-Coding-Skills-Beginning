# %%
# isupper(), islower(), upper(), lower()

s="GEEKSFORGEEKS"
print(s.isupper())

s='GeeksforGeeks'
print(s.isupper())
# Out:
# True
# False

# %%
#lower() Method

s='GEEKSFORGEEKS'
print(s.lower())

s='GeeksForGeeks'
print(s.lower())
# Out:
# geeksforgeeks
# geeksforgeeks

# %%
# Applications: Count Uppercase, Lowercase Letters and Spaces:

s='GeeksforGeeks is a computer Science portal for Geeks'
ns=''
cu=0
cl=0
cs=0

for ch in s:
    if ch.isupper():
        cu +=1
        ns +=ch.lower()
    elif ch.islower():
        cl +=1
        ns +=ch.upper()
    elif ch.isspace():
            cs +=1
            ns +=ch

            print('In original String:')
            print('Uppercase - ', cu)
            print('Lowercase:', cl)
            print('Spaces -', cs)
            print('After changing cases:')
            print(ns)
# Out:
# In original String:
# Uppercase -  2
# Lowercase: 11
# Spaces - 1
# After changing cases:
# gEEKSFORgEEKS
# In original String:
# Uppercase -  2
# Lowercase: 13
# Spaces - 2
# After changing cases:
# gEEKSFORgEEKS IS
# In original String:
# Uppercase -  2
# Lowercase: 14
# Spaces - 3
# After changing cases:
# gEEKSFORgEEKS IS A
# In original String:
# Uppercase -  2
# Lowercase: 22
# Spaces - 4
# After changing cases:
# gEEKSFORgEEKS IS A COMPUTER
# In original String:
# Uppercase -  3
# Lowercase: 28
# Spaces - 5
# After changing cases:
# gEEKSFORgEEKS IS A COMPUTER sCIENCE
# In original String:
# Uppercase -  3
# Lowercase: 34
# Spaces - 6
# After changing cases:
# gEEKSFORgEEKS IS A COMPUTER sCIENCE PORTAL
# In original String:
# Uppercase -  3
# Lowercase: 37
# Spaces - 7
# After changing cases:
# gEEKSFORgEEKS IS A COMPUTER sCIENCE PORTAL FOR
