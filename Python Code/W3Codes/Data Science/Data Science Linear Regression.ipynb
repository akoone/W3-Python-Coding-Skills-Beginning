# %%
# Data Science - Linear Regression
# Least Square Method


import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

full_health_data = pd.read_csv("exercise_data.csv", header=0, sep=",")

x = full_health_data["Average_Pulse"]
y = full_health_data ["Calorie_Burnage"]

slope, intercept, r,p,std_err=stats.linregress(x,y)

def myfunc(x):
    return slope*x+intercept

mymodel=list(map(myfunc,x))


plt.scatter(x,y)
plt.plot(x,slope*x+intercept)
plt.ylim(ymin=0,ymax=2000)
plt.xlim(xmin=0,xmax=200)
plt.xlabel('Average_Pulse')
plt.ylabel('Calorie_Burnage')
plt.show()

# %%
# Regression Table 


import pandas as pd
import statsmodels.formula.api as smf


full_health_data=pd.read_csv('exercise_data.csv', header=0,sep=',')

model=smf.ols('Calorie_Burnage ~ Average_Pulse',data=full_health_data)
results=model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Calorie_Burnage   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 5.795e+29
# Date:                Mon, 09 Jun 2025   Prob (F-statistic):          9.93e-117
# Time:                        00:26:59   Log-Likelihood:                 284.50
# No. Observations:                  10   AIC:                            -565.0
# Df Residuals:                       8   BIC:                            -564.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        80.0000   2.72e-13   2.94e+14      0.000      80.000      80.000
# ...

# %%
def Predict_Calorie_Burnage(Average_Pulse):
    return(.3296*Average_Pulse+346.8662)

print(Predict_Calorie_Burnage(120))
print(Predict_Calorie_Burnage(130))
print(Predict_Calorie_Burnage(140))
print(Predict_Calorie_Burnage(150))
print(Predict_Calorie_Burnage(180))
# Out:
# 386.4182
# 389.7142
# 393.0102
# 396.3062
# 406.1942

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

full_health_data=pd.read_csv('exercise_data.csv', header=0, sep=',')

x=full_health_data['Duration']
y=full_health_data['Calorie_Burnage']


slope, intercept, r,p,std_err=stats.linregress(x,y)


def myfunc(x):
    return slope*x+intercept


mymodel=list(map(myfunc,x))
print(mymodel)



plt.scatter(x,y)
plt.plot(x,mymodel)
plt.ylim(ymin=0,ymax=2000)
plt.xlim(xmin=0,xmax=200)
plt.xlabel('Duration')
plt.ylabel('Predict_Calorie_Burnage')

plt.show()
# Out:
# [np.float64(244.28571428571428), np.float64(244.28571428571428), np.float64(271.42857142857144), np.float64(271.42857142857144), np.float64(271.42857142857144), np.float64(298.57142857142856), np.float64(298.57142857142856), np.float64(298.57142857142856), np.float64(325.7142857142857), np.float64(325.7142857142857)]

# %%
import pandas as pd
import statsmodels.formula.api as smf

full_health_data=pd.read_csv('exercise_data.csv', header=0,sep=',')


model=smf.ols('Calorie_Burnage ~ Average_Pulse+Duration', data=full_health_data)
results=model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Calorie_Burnage   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.399e+29
# Date:                Mon, 09 Jun 2025   Prob (F-statistic):          1.19e-101
# Time:                        00:58:00   Log-Likelihood:                 284.22
# No. Observations:                  10   AIC:                            -562.4
# Df Residuals:                       7   BIC:                            -561.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept        80.0000   6.53e-13   1.23e+14      0.000      80.000      80.000
# ...

# %%
def Predict_Calorie_Burnage(Average_Pulse, Duration):
    return(3.1695*Average_Pulse+5.8434*Duration-334.5194)


print(Predict_Calorie_Burnage(110,60))
print(Predict_Calorie_Burnage(140,45))
print(Predict_Calorie_Burnage(175,20))
# Out:
# 364.7296
# 372.1636
# 337.01110000000006
