# %%
a=9
b=5
c=9


#Output
print(a==c)
print(a==b)
# Out:
# True
# False

# %%
# Inequal Operators a!=b

a=9
b=5
c=9
#Output
print(a!=b)
print(a!=c)
# Out:
# True
# False

# %%
# Greater than Sign a>b
a=9
b=5
#Output
print(a>b)
print(b>a)
# Out:
# True
# False

# %%
#Greater than or Equal to sign x>=y
a=9
b=5
c=9
#Output
print(a>=b)
print(a>=c)
print(b>=a)
# Out:
# True
# True
# False

# %%
#Less than or Equal to Sign x<=y
a=9
b=5
c=9
#Output
print(a<=b)
print(a<=c)
print(b<=a)
# Out:
# False
# True
# True

# %%
#Changing Comparison Operators
a=5

#changing comparison operators
print(1<a<10)
print(10>a<+9)
print(5!=a>4)
print(a<10<a*10==50)
# Out:
# True
# True
# False
# True
