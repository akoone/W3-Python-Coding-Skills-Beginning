# %%
# The Python Operators are used to perform operations on values and variables.
#Moduls Assignment Operator is used to take the moduls, that is, it first divides the operands and then takes the remainder and assign it to the left operand.

a=7
b=3
a%=b
print(a)
# Out:
# 1

# %%
a=10
b=5
a%=b
print(a)
# Out:
# 0

# %%
#Floor division assignment operator


a=3
b=5

a//=b

print(a)
# Out:
# 0

# %%
# Exponention Assignment Operator


a=3
b=5

a**=b
print(a)
# Out:
# 243

# %%
#Bitewise AND Assignment Operator
a=3
b=5
a&=b
print(a)
# Out:
# 1

# %%
#Bitewise Or Assignment Operator
a=3
b=5

a|=b

print(a)
# Out:
# 7

# %%
# Bitewise XOR Assignment Operator

a=3
b=5
a^=b
print(a)
# Out:
# 6

# %%
# Bitewise Right Shift Assignment Operator

a=3
b=5

a>>=b
print(a)
# Out:
# 0

# %%
# Warlus Operator is a new assignment operator in python. this operator is used to assign a value to a variable within an expression.

a=[1,2,3,4,5]

while(x:=len(a))>2:
    a.pop()
    print(x)
# Out:
# 5
# 4
# 3
