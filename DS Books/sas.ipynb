# %%
import pandas as pd
import pyreadstat

# Load SPSS file
"C:\Users\hpple\Desktop\CY08MSP_STU_COG.SAS7BDAT"# replace with your local path
df, meta = pyreadstat.read_sav(file_path)

# Quick check
print(df.columns)
print(df.head())
# Out:
#   Cell In[2], line 5
#     "C:\Users\hpple\Desktop\CY08MSP_STU_COG.SAS7BDAT"# replace with your local path
#     ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
file_path = r"C:\Users\hpple\Desktop\CY08MSP_STU_COG.SAS7BDAT"

# %%
file_path = "C:\\Users\\hpple\\Desktop\\CY08MSP_STU_COG.SAS7BDAT"

# %%
file_path = "C:/Users/hpple/Desktop/CY08MSP_STU_COG.SAS7BDAT"

# %%
import pyreadstat
df, meta = pyreadstat.read_sas7bdat(file_path)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pyreadstat
#       2 df, meta = pyreadstat.read_sas7bdat(file_path)
#       3 print(df.head())
#
# ModuleNotFoundError: No module named 'pyreadstat'
